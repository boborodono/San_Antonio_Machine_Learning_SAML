# %% [markdown]
# # Converting "Stroke Prediction Dataset" from CSV into Parquet with Pandas

# %% [markdown]
# ## Import Dependencies

# %%
import csv
import os
import pandas as pd
import pyarrow.parquet as pq

# %% [markdown]
# ## Load and Read Dataset into Pandas DataFrame

# %%
 #? Load File
Path = "../../../Resources/healthcare-dataset-stroke-data.csv"

#? Read the CSVs into a dataframe
stroke_df = pd.read_csv(Path)

# %% [markdown]
# ## Show DataFrame

# %%
stroke_df.sample(10)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 1601  49152  Female  40.0             0              0           No
# 2798  28108  Female  62.0             0              0          Yes
# 2414  69502  Female  52.0             1              0          Yes
# 1968   2070    Male  52.0             0              0          Yes
# 2605  35152    Male  10.0             0              0           No
# 4633  72289  Female  44.0             0              0          Yes
# 3718  39632  Female  53.0             0              0          Yes
# 1769  32452  Female  82.0             0              1          Yes
# 3740   5380  Female  26.0             0              0          Yes
# 2655  26474  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 1601        Private          Rural              70.45  23.3         smokes
# 2798        Private          Rural              82.57  27.5        Unknown
# 2414        Private          Urban             155.86  27.2         smokes
# 1968        Private          Urban              95.85  29.6         smokes
# 2605       children          Urban              76.92  15.8        Unknown
# 4633        Private          Rural              68.42  43.2         smokes
# 3718        Private          Urban             209.50  41.8   never smoked
# 1769  Self-employed          Rural             211.88  28.7   never smoked
# 3740        Private          Urban              91.35  23.8   never smoked
# 2655       Govt_job          Urban              97.16  33.1        Unknown
#
#       stroke
# 1601       0
# 2798       0
# 2414       0
# 1968       0
# 2605       0
# 4633       0
# 3718       0
# 1769       0
# 3740       0
# 2655       0

# %% [markdown]
# ## What is the size of the dataset and what are the datatypes?

# %%
stroke_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# ## Convert DataFrame to Parquet

# %%
stroke_df.to_parquet('stroke.parquet.gzip', compression='gzip', index=False)
