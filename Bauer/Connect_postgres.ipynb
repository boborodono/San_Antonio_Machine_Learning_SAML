# %%
import pandas as pd
import pyarrow.parquet
import os
import sqlite3
import psycopg2
from sqlalchemy import create_engine

# %%
stroke_data_whole = pd.read_parquet('Resources/cleaned_dataset/clean_stroke.parquet.gzip')
stroke_data_no_null_bmi =pd.read_parquet('Resources/cleaned_dataset/clean_stroke_bmi_removed.parquet.gzip')

# %%
stroke_medical = stroke_data_whole.drop(columns = ['Ever_Married',
       'Work_Type', 'Residence_Type'])
stroke_medical.head()
# Out:
#    ID#  Gender  Age  Hypertension  Heart_Disease  Avg_Glucose_Lvl   BMI  \
# 0    1    Male   67             0              1           228.69  36.6
# 1    2  Female   61             0              0           202.21   NaN
# 2    3    Male   80             0              1           105.92  32.5
# 3    4  Female   49             0              0           171.23  34.4
# 4    5  Female   79             1              0           174.12  24.0
#
#     Smoker  Stroke
# 0   Former       1
# 1    Never       1
# 2    Never       1
# 3  Current       1
# 4    Never       1

# %%
stroke_medical_no_bmi = stroke_data_no_null_bmi.drop(columns = ['Ever_Married',
       'Work_Type', 'Residence_Type'])
stroke_medical_no_bmi.head()
# Out:
#    ID#  Gender  Age  Hypertension  Heart_Disease  Avg_Glucose_Lvl   BMI  \
# 0    1    Male   67             0              1           228.69  36.6
# 1    3    Male   80             0              1           105.92  32.5
# 2    4  Female   49             0              0           171.23  34.4
# 3    5  Female   79             1              0           174.12  24.0
# 4    6    Male   81             0              0           186.21  29.0
#
#     Smoker  Stroke
# 0   Former       1
# 1    Never       1
# 2  Current       1
# 3    Never       1
# 4   Former       1

# %%
stroke_personal = stroke_data_whole.drop(columns = ["Gender", "Age",'Hypertension', 'Heart_Disease',
       'Work_Type', 'Residence_Type', 'Stroke'])
stroke_personal.head()
# Out:
#    ID# Ever_Married  Avg_Glucose_Lvl   BMI   Smoker
# 0    1          Yes           228.69  36.6   Former
# 1    2          Yes           202.21   NaN    Never
# 2    3          Yes           105.92  32.5    Never
# 3    4          Yes           171.23  34.4  Current
# 4    5          Yes           174.12  24.0    Never

# %%
engine = create_engine('postgresql://{username}:{pass}@localhost:{host}/SanAntonio_Strok_Pred')
stroke_medical.to_sql('medical', engine)
stroke_medical.to_sql('medical_no_bmi', engine)
stroke_personal.to_sql('personal', engine)
