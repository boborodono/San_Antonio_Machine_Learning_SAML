# %%
import numpy as np
from sqlalchemy import create_engine
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.svm import SVC
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

# %%
filepath = '../Resources/BMI_Datasets/underweight.csv'
medical_df = pd.read_csv(filepath)
medical_df.head(10)
# Out:
#    ID#  Gender  Age  Hypertension  Heart_Disease Ever_Married      Work_Type  \
# 0  231  Female   81             0              0          Yes  Self-employed
# 1  250    Male    3             0              0           No       children
# 2  252  Female    8             0              0           No        Private
# 3  256  Female   52             0              0          Yes        Private
# 4  283  Female    3             0              0           No       children
# 5  291    Male   13             0              0           No       children
# 6  322    Male   11             0              0           No       children
# 7  370  Female    4             0              0           No       children
# 8  377  Female    0             0              0           No       children
# 9  381    Male    4             0              0           No       children
#
#   Residence_Type  Avg_Glucose_Lvl   BMI   Smoker  Stroke
# 0          Rural            81.95  16.9    Never       1
# 1          Rural            95.12  18.0  Unknown       0
# 2          Urban           110.89  17.6  Unknown       0
# 3          Urban            77.59  17.7   Former       0
# 4          Urban            73.74  16.0  Unknown       0
# 5          Urban           114.84  18.3  Unknown       0
# 6          Rural            79.03  16.5  Unknown       0
# 7          Rural            93.25  16.6  Unknown       0
# 8          Rural            88.11  15.5  Unknown       0
# 9          Rural           106.22  16.7  Unknown       0

# %%
# Drop ID# column
medical_df.drop(columns=['ID#'], inplace=True)
medical_df.head()
# Out:
#    Gender  Age  Hypertension  Heart_Disease Ever_Married      Work_Type  \
# 0  Female   81             0              0          Yes  Self-employed
# 1    Male    3             0              0           No       children
# 2  Female    8             0              0           No        Private
# 3  Female   52             0              0          Yes        Private
# 4  Female    3             0              0           No       children
#
#   Residence_Type  Avg_Glucose_Lvl   BMI   Smoker  Stroke
# 0          Rural            81.95  16.9    Never       1
# 1          Rural            95.12  18.0  Unknown       0
# 2          Urban           110.89  17.6  Unknown       0
# 3          Urban            77.59  17.7   Former       0
# 4          Urban            73.74  16.0  Unknown       0

# %%
medical_df['Stroke'].value_counts()
# Out:
# 0    336
# 1      1
# Name: Stroke, dtype: int64

# %%
# Need at least 2 positive stroke cases to continue
