# %%
import pyforest
from pyforest import *

import os
pyforest.active_imports()
# Out:
# import pandas as pd
# ['import pandas as pd']

# %% [markdown]
# ## Prints the FOLDER STRUCTURE from the Root

# %%
path1 = r'C:\Users\Boborodono\Desktop\San_Antonio\Resources'
print("List of all folders and filepaths in '% s':" % path1) 
def list_files(dir):
    r = []
    for root, dirs, files in os.walk(dir):
        for name in files:
            filepath = root + os.sep + name
            r.append(os.path.join(root, name))
        print(root)
    return r

print(list_files(path1))
# Out:
# List of all folders and filepaths in 'C:\Users\Boborodono\Desktop\San_Antonio\Resources':
# C:\Users\Boborodono\Desktop\San_Antonio\Resources
# C:\Users\Boborodono\Desktop\San_Antonio\Resources\Age_Datasets
# C:\Users\Boborodono\Desktop\San_Antonio\Resources\Age_Datasets\Parquet
# C:\Users\Boborodono\Desktop\San_Antonio\Resources\BMI_Datasets
# C:\Users\Boborodono\Desktop\San_Antonio\Resources\BMI_Datasets\Parquet
# C:\Users\Boborodono\Desktop\San_Antonio\Resources\Cleaned_Dataset
# C:\Users\Boborodono\Desktop\San_Antonio\Resources\Cleaned_Dataset\Parquet
# C:\Users\Boborodono\Desktop\San_Antonio\Resources\Datasets_List
# C:\Users\Boborodono\Desktop\San_Antonio\Resources\Glucose_Datasets
# C:\Users\Boborodono\Desktop\San_Antonio\Resources\Glucose_Datasets\Parquet
# ['C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\healthcare-dataset-stroke-data.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Boomer_stroke.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\gen_X_stroke.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\gen_Y_stroke.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\gen_Z_stroke.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\greatest_gen_stroke.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\Boomer_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\gen_X_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\gen_Y_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\gen_Z_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\greatest_gen_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\healthy_weight.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\obese_high_risk.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\obese_low_risk.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\obese_medium_risk.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\overweight.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\underweight.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\healthy_weight.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\obese_high_risk.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\obese_low_risk.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\obese_medium_risk.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\overweight.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\underweight.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Cleaned_Dataset\\clean_stroke.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Cleaned_Dataset\\clean_stroke_bmi_removed.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Cleaned_Dataset\\Parquet\\clean_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Cleaned_Dataset\\Parquet\\clean_stroke_bmi_removed.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Datasets_List\\Datasets_List.ipynb', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\diabetic_glucose.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\normal_glucose.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\prediabetic_glucose.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\Parquet\\diabetic_glucose.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\Parquet\\normal_glucose.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\Parquet\\prediabetic_glucose.parquet.gzip']

# %% [markdown]
# ## Prints the "csv" file names in a specific folder

# %%
# Directory to be scanned
path2 = "C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets"

# Using os.scandir() method, scan the specified directory
# and yield os.DirEntry object for each file and sub directory

print("List of all the files in the path '% s':" % path2)
with os.scandir(path2) as itr:
    for entry in itr:
        # Check if the entry in a file
        if entry.name.endswith(".csv") and entry.is_file():
            # Print entry filename
            print(entry.name)
# Out:
# List of all the files in the path 'C:\Users\Boborodono\Desktop\San_Antonio\Resources\BMI_Datasets':
# healthy_weight.csv
# obese_high_risk.csv
# obese_low_risk.csv
# obese_medium_risk.csv
# overweight.csv
# underweight.csv

# %% [markdown]
# # LIST COMPREHENSION:

# %% [markdown]
# ### Prints all ".gzip" files in the Root and subdirectories

# %%
path3 = "C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources"

print("List of all the files in the path '% s':" % path3)
def list_comp_filepath(dir):
    dataset_list = []
    # Using list comprehension
    return[name for root, dirs, files in os.walk(dir) for name in files if name.endswith(".gzip")]


comp_filepaths = list_comp_filepath(path3)  
print(comp_filepaths)
# Out:
# List of all the files in the path 'C:\Users\Boborodono\Desktop\San_Antonio\Resources':
# ['Boomer_stroke.parquet.gzip', 'gen_X_stroke.parquet.gzip', 'gen_Y_stroke.parquet.gzip', 'gen_Z_stroke.parquet.gzip', 'greatest_gen_stroke.parquet.gzip', 'healthy_weight.parquet.gzip', 'obese_high_risk.parquet.gzip', 'obese_low_risk.parquet.gzip', 'obese_medium_risk.parquet.gzip', 'overweight.parquet.gzip', 'underweight.parquet.gzip', 'clean_stroke.parquet.gzip', 'clean_stroke_bmi_removed.parquet.gzip', 'diabetic_glucose.parquet.gzip', 'normal_glucose.parquet.gzip', 'prediabetic_glucose.parquet.gzip']

# %% [markdown]
# ### Prints all the "filepaths" for "parquet" files in Root and subdirectories

# %%
print("List of all the filepaths in Root Directory '% s':" % path3)
def list_comp_files(dir):
    dataset_list = []
    # Using list comprehension
    return[os.path.join(root, name) for root, dirs, files in os.walk(dir) for name in files if name.endswith(".gzip")]


comp_names = list_comp_files(path3)  
print(comp_names)
# Out:
# List of all the filepaths in Root Directory 'C:\Users\Boborodono\Desktop\San_Antonio\Resources':
# ['C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\Boomer_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\gen_X_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\gen_Y_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\gen_Z_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\greatest_gen_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\healthy_weight.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\obese_high_risk.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\obese_low_risk.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\obese_medium_risk.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\overweight.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\underweight.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Cleaned_Dataset\\Parquet\\clean_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Cleaned_Dataset\\Parquet\\clean_stroke_bmi_removed.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\Parquet\\diabetic_glucose.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\Parquet\\normal_glucose.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\Parquet\\prediabetic_glucose.parquet.gzip']

# %% [markdown]
# # FOR LOOPS:

# %% [markdown]
# ### Prints all the "file names" for "csv" files in Root and subdirectories

# %%
path4 = r'C:\Users\Boborodono\Desktop\San_Antonio\Resources'
print("List of all \"filenames\" in '% s':" % path4) 
def list_filenames(dir):
    filenames = []
    for root, dirs, files in os.walk(dir):
        for name in files:
            filename = name
            if filename.endswith(".csv"):
                filenames.append(name)
    return filenames


print(list_filenames(path4))
csv_file_names = list_filenames(path4)
# Out:
# List of all "filenames" in 'C:\Users\Boborodono\Desktop\San_Antonio\Resources':
# ['healthcare-dataset-stroke-data.csv', 'Boomer_stroke.csv', 'gen_X_stroke.csv', 'gen_Y_stroke.csv', 'gen_Z_stroke.csv', 'greatest_gen_stroke.csv', 'healthy_weight.csv', 'obese_high_risk.csv', 'obese_low_risk.csv', 'obese_medium_risk.csv', 'overweight.csv', 'underweight.csv', 'clean_stroke.csv', 'clean_stroke_bmi_removed.csv', 'diabetic_glucose.csv', 'normal_glucose.csv', 'prediabetic_glucose.csv']

# %%
path5 = r'C:\Users\Boborodono\Desktop\San_Antonio\Resources'
print("List of all \"filepaths\" in '% s':" % path5) 
def list_filepaths(path5):
    filepaths = []
    for root, dirs, files in os.walk(path5):
        for name in files:
            filepath = root + os.sep + name
            if filepath.endswith(".csv"):
                filepaths.append(os.path.join(root, name))
    return filepaths


print(list_filepaths(path5))
csv_file_paths = list_filepaths(path5)
# Out:
# List of all "filepaths" in 'C:\Users\Boborodono\Desktop\San_Antonio\Resources':
# ['C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\healthcare-dataset-stroke-data.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Boomer_stroke.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\gen_X_stroke.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\gen_Y_stroke.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\gen_Z_stroke.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\greatest_gen_stroke.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\healthy_weight.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\obese_high_risk.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\obese_low_risk.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\obese_medium_risk.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\overweight.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\underweight.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Cleaned_Dataset\\clean_stroke.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Cleaned_Dataset\\clean_stroke_bmi_removed.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\diabetic_glucose.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\normal_glucose.csv', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\prediabetic_glucose.csv']

# %% [markdown]
# # FOR LOOPS:

# %% [markdown]
# ### Prints all the "file names" for "gzip" files in Root and subdirectories

# %%
path4 = r'C:\Users\Boborodono\Desktop\San_Antonio\Resources'
print("List of all \"filenames\" in '% s':" % path4) 
def list_filenames(dir):
    filenames = []
    for root, dirs, files in os.walk(dir):
        for name in files:
            filename = name
            if filename.endswith(".gzip"):
                filenames.append(name)
    return filenames


print(list_filenames(path4))
parquet_file_names = list_filenames(path4)
# Out:
# List of all "filenames" in 'C:\Users\Boborodono\Desktop\San_Antonio\Resources':
# ['Boomer_stroke.parquet.gzip', 'gen_X_stroke.parquet.gzip', 'gen_Y_stroke.parquet.gzip', 'gen_Z_stroke.parquet.gzip', 'greatest_gen_stroke.parquet.gzip', 'healthy_weight.parquet.gzip', 'obese_high_risk.parquet.gzip', 'obese_low_risk.parquet.gzip', 'obese_medium_risk.parquet.gzip', 'overweight.parquet.gzip', 'underweight.parquet.gzip', 'clean_stroke.parquet.gzip', 'clean_stroke_bmi_removed.parquet.gzip', 'diabetic_glucose.parquet.gzip', 'normal_glucose.parquet.gzip', 'prediabetic_glucose.parquet.gzip']

# %%
print("List of all \"filepaths\" in '% s':" % path4) 
def list_filepaths(path4):
    filepaths = []
    for root, dirs, files in os.walk(path4):
        for name in files:
            filepath = root + os.sep + name
            if filepath.endswith(".gzip"):
                filepaths.append(os.path.join(root, name))
    return filepaths


print(list_filepaths(path4))
parquet_file_paths = list_filepaths(path4)
# Out:
# List of all "filepaths" in 'C:\Users\Boborodono\Desktop\San_Antonio\Resources':
# ['C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\Boomer_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\gen_X_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\gen_Y_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\gen_Z_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Age_Datasets\\Parquet\\greatest_gen_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\healthy_weight.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\obese_high_risk.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\obese_low_risk.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\obese_medium_risk.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\overweight.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\BMI_Datasets\\Parquet\\underweight.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Cleaned_Dataset\\Parquet\\clean_stroke.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Cleaned_Dataset\\Parquet\\clean_stroke_bmi_removed.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\Parquet\\diabetic_glucose.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\Parquet\\normal_glucose.parquet.gzip', 'C:\\Users\\Boborodono\\Desktop\\San_Antonio\\Resources\\Glucose_Datasets\\Parquet\\prediabetic_glucose.parquet.gzip']

# %% [markdown]
# # CSV - Create a Table cataloguing files in Root + sub-ds and developing shortcuts for easy import and reference

# %%
# Using Greek Letters to easily import datasets
greek_letters = ['alpha ','beta ','gamma ','delta ','epsilon','zeta','eta','theta','iota','kappa','lambda','mu','nu','xi','omicron','pi','rho','sigma','tau','upsilon','phi','chi','psi ','omega']

# Number of datasets
csv_datasets_count = len(csv_file_names)
print(f"The number of '.csv' files in the Root folder is: " + str(csv_datasets_count))

# Create Dictionary 
df_start = {"Greek_Letter_Variable": (greek_letters[0:csv_datasets_count]),
            "File_Name": (csv_file_names[0:]), 
            "File_Paths": (csv_file_paths[0:])}

# Create DataFrame
csv_datasets_df = pd.DataFrame(data=df_start)
csv_datasets_df

# Add a column concatenating the greek letters and file paths
csv_datasets_df["Copy_This"] = csv_datasets_df["Greek_Letter_Variable"] + " = " + '\"' + csv_datasets_df["File_Paths"] + '\"'
csv_datasets_df
# Out:
# The number of '.csv' files in the Root folder is: 17
#    Greek_Letter_Variable                           File_Name  \
# 0                 alpha   healthcare-dataset-stroke-data.csv
# 1                  beta                    Boomer_stroke.csv
# 2                 gamma                     gen_X_stroke.csv
# 3                 delta                     gen_Y_stroke.csv
# 4                epsilon                    gen_Z_stroke.csv
# 5                   zeta             greatest_gen_stroke.csv
# 6                    eta                  healthy_weight.csv
# 7                  theta                 obese_high_risk.csv
# 8                   iota                  obese_low_risk.csv
# 9                  kappa               obese_medium_risk.csv
# 10                lambda                      overweight.csv
# 11                    mu                     underweight.csv
# 12                    nu                    clean_stroke.csv
# 13                    xi        clean_stroke_bmi_removed.csv
# 14               omicron                diabetic_glucose.csv
# 15                    pi                  normal_glucose.csv
# 16                   rho             prediabetic_glucose.csv
#
#                                            File_Paths  \
# 0   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 1   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 2   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 3   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 4   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 5   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 6   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 7   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 8   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 9   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 10  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 11  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 12  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 13  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 14  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 15  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 16  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
#
#                                             Copy_This
# 0   alpha  = "C:\Users\Boborodono\Desktop\San_Anto...
# 1   beta  = "C:\Users\Boborodono\Desktop\San_Anton...
# 2   gamma  = "C:\Users\Boborodono\Desktop\San_Anto...
# 3   delta  = "C:\Users\Boborodono\Desktop\San_Anto...
# 4   epsilon = "C:\Users\Boborodono\Desktop\San_Ant...
# 5   zeta = "C:\Users\Boborodono\Desktop\San_Antoni...
# 6   eta = "C:\Users\Boborodono\Desktop\San_Antonio...
# 7   theta = "C:\Users\Boborodono\Desktop\San_Anton...
# 8   iota = "C:\Users\Boborodono\Desktop\San_Antoni...
# 9   kappa = "C:\Users\Boborodono\Desktop\San_Anton...
# 10  lambda = "C:\Users\Boborodono\Desktop\San_Anto...
# 11  mu = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 12  nu = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 13  xi = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 14  omicron = "C:\Users\Boborodono\Desktop\San_Ant...
# 15  pi = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 16  rho = "C:\Users\Boborodono\Desktop\San_Antonio...

# %%
# Reorder columns
csv_datasets_df = csv_datasets_df[['Greek_Letter_Variable', 'File_Name', 'Copy_This', 'File_Paths']]

# %%
# Sort Table by "File_Paths"
csv_datasets_df.sort_values(by = ['File_Paths'], ascending=True, inplace = True)
csv_datasets_df
# Out:
#    Greek_Letter_Variable                           File_Name  \
# 1                  beta                    Boomer_stroke.csv
# 2                 gamma                     gen_X_stroke.csv
# 3                 delta                     gen_Y_stroke.csv
# 4                epsilon                    gen_Z_stroke.csv
# 5                   zeta             greatest_gen_stroke.csv
# 6                    eta                  healthy_weight.csv
# 7                  theta                 obese_high_risk.csv
# 8                   iota                  obese_low_risk.csv
# 9                  kappa               obese_medium_risk.csv
# 10                lambda                      overweight.csv
# 11                    mu                     underweight.csv
# 12                    nu                    clean_stroke.csv
# 13                    xi        clean_stroke_bmi_removed.csv
# 14               omicron                diabetic_glucose.csv
# 15                    pi                  normal_glucose.csv
# 16                   rho             prediabetic_glucose.csv
# 0                 alpha   healthcare-dataset-stroke-data.csv
#
#                                             Copy_This  \
# 1   beta  = "C:\Users\Boborodono\Desktop\San_Anton...
# 2   gamma  = "C:\Users\Boborodono\Desktop\San_Anto...
# 3   delta  = "C:\Users\Boborodono\Desktop\San_Anto...
# 4   epsilon = "C:\Users\Boborodono\Desktop\San_Ant...
# 5   zeta = "C:\Users\Boborodono\Desktop\San_Antoni...
# 6   eta = "C:\Users\Boborodono\Desktop\San_Antonio...
# 7   theta = "C:\Users\Boborodono\Desktop\San_Anton...
# 8   iota = "C:\Users\Boborodono\Desktop\San_Antoni...
# 9   kappa = "C:\Users\Boborodono\Desktop\San_Anton...
# 10  lambda = "C:\Users\Boborodono\Desktop\San_Anto...
# 11  mu = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 12  nu = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 13  xi = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 14  omicron = "C:\Users\Boborodono\Desktop\San_Ant...
# 15  pi = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 16  rho = "C:\Users\Boborodono\Desktop\San_Antonio...
# 0   alpha  = "C:\Users\Boborodono\Desktop\San_Anto...
#
#                                            File_Paths
# 1   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 2   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 3   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 4   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 5   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 6   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 7   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 8   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 9   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 10  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 11  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 12  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 13  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 14  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 15  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 16  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 0   C:\Users\Boborodono\Desktop\San_Antonio\Resour...

# %%
# Make new more compact DataFrame
csv_reference_df = csv_datasets_df[['File_Name', 'Copy_This']]
csv_reference_df
# Out:
#                              File_Name  \
# 1                    Boomer_stroke.csv
# 2                     gen_X_stroke.csv
# 3                     gen_Y_stroke.csv
# 4                     gen_Z_stroke.csv
# 5              greatest_gen_stroke.csv
# 6                   healthy_weight.csv
# 7                  obese_high_risk.csv
# 8                   obese_low_risk.csv
# 9                obese_medium_risk.csv
# 10                      overweight.csv
# 11                     underweight.csv
# 12                    clean_stroke.csv
# 13        clean_stroke_bmi_removed.csv
# 14                diabetic_glucose.csv
# 15                  normal_glucose.csv
# 16             prediabetic_glucose.csv
# 0   healthcare-dataset-stroke-data.csv
#
#                                             Copy_This
# 1   beta  = "C:\Users\Boborodono\Desktop\San_Anton...
# 2   gamma  = "C:\Users\Boborodono\Desktop\San_Anto...
# 3   delta  = "C:\Users\Boborodono\Desktop\San_Anto...
# 4   epsilon = "C:\Users\Boborodono\Desktop\San_Ant...
# 5   zeta = "C:\Users\Boborodono\Desktop\San_Antoni...
# 6   eta = "C:\Users\Boborodono\Desktop\San_Antonio...
# 7   theta = "C:\Users\Boborodono\Desktop\San_Anton...
# 8   iota = "C:\Users\Boborodono\Desktop\San_Antoni...
# 9   kappa = "C:\Users\Boborodono\Desktop\San_Anton...
# 10  lambda = "C:\Users\Boborodono\Desktop\San_Anto...
# 11  mu = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 12  nu = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 13  xi = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 14  omicron = "C:\Users\Boborodono\Desktop\San_Ant...
# 15  pi = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 16  rho = "C:\Users\Boborodono\Desktop\San_Antonio...
# 0   alpha  = "C:\Users\Boborodono\Desktop\San_Anto...

# %%
# Reference Dataframe
csv_quick_data_import_df = csv_datasets_df[['File_Paths']]
csv_quick_data_import_df
# Out:
#                                            File_Paths
# 1   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 2   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 3   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 4   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 5   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 6   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 7   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 8   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 9   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 10  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 11  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 12  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 13  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 14  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 15  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 16  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 0   C:\Users\Boborodono\Desktop\San_Antonio\Resour...

# %%
# Export CSV File
csv_datasets_df.to_csv(r'..\..\Resources\Datasets_List\CSV\datasets_full_csv.csv', index=False)
csv_reference_df.to_csv(r'..\..\Resources\Datasets_List\CSV\rseference_datasets_csv.csv', index=False)
csv_quick_data_import_df.to_csv(r'..\..\Resources\Datasets_List\CSV\quick_datasets_csv.csv', index=False)

# %% [markdown]
# # Parquet - Create a Table cataloguing files in Root + sub-ds and developing shortcuts for easy import and reference

# %%
# Using Greek Letters to easily import datasets
greek_letters = ['alpha ','beta ','gamma ','delta ','epsilon','zeta','eta','theta','iota','kappa','lambda','mu','nu','xi','omicron','pi','rho','sigma','tau','upsilon','phi','chi','psi ','omega']

# Number of datasets
parquet_datasets_count = len(parquet_file_names)
print(f"The number of '.gzip' files in the Root folder is: " + str(parquet_datasets_count))

# Create Dictionary 
df_start = {"Greek_Letter_Variable": (greek_letters[0:parquet_datasets_count]),
            "File_Name": (parquet_file_names[0:]), 
            "File_Paths": (parquet_file_paths[0:])}

# Create DataFrame
parquet_datasets_df = pd.DataFrame(data=df_start)
parquet_datasets_df

# Add a column concatenating the greek letters and file paths
parquet_datasets_df["Copy_This"] = parquet_datasets_df["Greek_Letter_Variable"] + " = " + '\"' + parquet_datasets_df["File_Paths"] + '\"'
parquet_datasets_df
# Out:
# The number of '.gzip' files in the Root folder is: 16
#    Greek_Letter_Variable                              File_Name  \
# 0                 alpha              Boomer_stroke.parquet.gzip
# 1                  beta               gen_X_stroke.parquet.gzip
# 2                 gamma               gen_Y_stroke.parquet.gzip
# 3                 delta               gen_Z_stroke.parquet.gzip
# 4                epsilon       greatest_gen_stroke.parquet.gzip
# 5                   zeta            healthy_weight.parquet.gzip
# 6                    eta           obese_high_risk.parquet.gzip
# 7                  theta            obese_low_risk.parquet.gzip
# 8                   iota         obese_medium_risk.parquet.gzip
# 9                  kappa                overweight.parquet.gzip
# 10                lambda               underweight.parquet.gzip
# 11                    mu              clean_stroke.parquet.gzip
# 12                    nu  clean_stroke_bmi_removed.parquet.gzip
# 13                    xi          diabetic_glucose.parquet.gzip
# 14               omicron            normal_glucose.parquet.gzip
# 15                    pi       prediabetic_glucose.parquet.gzip
#
#                                            File_Paths  \
# 0   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 1   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 2   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 3   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 4   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 5   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 6   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 7   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 8   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 9   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 10  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 11  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 12  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 13  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 14  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 15  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
#
#                                             Copy_This
# 0   alpha  = "C:\Users\Boborodono\Desktop\San_Anto...
# 1   beta  = "C:\Users\Boborodono\Desktop\San_Anton...
# 2   gamma  = "C:\Users\Boborodono\Desktop\San_Anto...
# 3   delta  = "C:\Users\Boborodono\Desktop\San_Anto...
# 4   epsilon = "C:\Users\Boborodono\Desktop\San_Ant...
# 5   zeta = "C:\Users\Boborodono\Desktop\San_Antoni...
# 6   eta = "C:\Users\Boborodono\Desktop\San_Antonio...
# 7   theta = "C:\Users\Boborodono\Desktop\San_Anton...
# 8   iota = "C:\Users\Boborodono\Desktop\San_Antoni...
# 9   kappa = "C:\Users\Boborodono\Desktop\San_Anton...
# 10  lambda = "C:\Users\Boborodono\Desktop\San_Anto...
# 11  mu = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 12  nu = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 13  xi = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 14  omicron = "C:\Users\Boborodono\Desktop\San_Ant...
# 15  pi = "C:\Users\Boborodono\Desktop\San_Antonio\...

# %%
# Reorder columns
parquet_datasets_df = parquet_datasets_df[['Greek_Letter_Variable', 'File_Name', 'Copy_This', 'File_Paths']]

# %%
# Sort Table by "File_Paths"
parquet_datasets_df.sort_values(by = ['File_Paths'], ascending=True, inplace = True)
parquet_datasets_df
# Out:
#    Greek_Letter_Variable                              File_Name  \
# 0                 alpha              Boomer_stroke.parquet.gzip
# 1                  beta               gen_X_stroke.parquet.gzip
# 2                 gamma               gen_Y_stroke.parquet.gzip
# 3                 delta               gen_Z_stroke.parquet.gzip
# 4                epsilon       greatest_gen_stroke.parquet.gzip
# 5                   zeta            healthy_weight.parquet.gzip
# 6                    eta           obese_high_risk.parquet.gzip
# 7                  theta            obese_low_risk.parquet.gzip
# 8                   iota         obese_medium_risk.parquet.gzip
# 9                  kappa                overweight.parquet.gzip
# 10                lambda               underweight.parquet.gzip
# 11                    mu              clean_stroke.parquet.gzip
# 12                    nu  clean_stroke_bmi_removed.parquet.gzip
# 13                    xi          diabetic_glucose.parquet.gzip
# 14               omicron            normal_glucose.parquet.gzip
# 15                    pi       prediabetic_glucose.parquet.gzip
#
#                                             Copy_This  \
# 0   alpha  = "C:\Users\Boborodono\Desktop\San_Anto...
# 1   beta  = "C:\Users\Boborodono\Desktop\San_Anton...
# 2   gamma  = "C:\Users\Boborodono\Desktop\San_Anto...
# 3   delta  = "C:\Users\Boborodono\Desktop\San_Anto...
# 4   epsilon = "C:\Users\Boborodono\Desktop\San_Ant...
# 5   zeta = "C:\Users\Boborodono\Desktop\San_Antoni...
# 6   eta = "C:\Users\Boborodono\Desktop\San_Antonio...
# 7   theta = "C:\Users\Boborodono\Desktop\San_Anton...
# 8   iota = "C:\Users\Boborodono\Desktop\San_Antoni...
# 9   kappa = "C:\Users\Boborodono\Desktop\San_Anton...
# 10  lambda = "C:\Users\Boborodono\Desktop\San_Anto...
# 11  mu = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 12  nu = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 13  xi = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 14  omicron = "C:\Users\Boborodono\Desktop\San_Ant...
# 15  pi = "C:\Users\Boborodono\Desktop\San_Antonio\...
#
#                                            File_Paths
# 0   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 1   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 2   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 3   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 4   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 5   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 6   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 7   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 8   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 9   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 10  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 11  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 12  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 13  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 14  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 15  C:\Users\Boborodono\Desktop\San_Antonio\Resour...

# %%
# Make new more compact DataFrame
parquet_reference_df = parquet_datasets_df[['File_Name', 'Copy_This']]
parquet_reference_df
# Out:
#                                 File_Name  \
# 0              Boomer_stroke.parquet.gzip
# 1               gen_X_stroke.parquet.gzip
# 2               gen_Y_stroke.parquet.gzip
# 3               gen_Z_stroke.parquet.gzip
# 4        greatest_gen_stroke.parquet.gzip
# 5             healthy_weight.parquet.gzip
# 6            obese_high_risk.parquet.gzip
# 7             obese_low_risk.parquet.gzip
# 8          obese_medium_risk.parquet.gzip
# 9                 overweight.parquet.gzip
# 10               underweight.parquet.gzip
# 11              clean_stroke.parquet.gzip
# 12  clean_stroke_bmi_removed.parquet.gzip
# 13          diabetic_glucose.parquet.gzip
# 14            normal_glucose.parquet.gzip
# 15       prediabetic_glucose.parquet.gzip
#
#                                             Copy_This
# 0   alpha  = "C:\Users\Boborodono\Desktop\San_Anto...
# 1   beta  = "C:\Users\Boborodono\Desktop\San_Anton...
# 2   gamma  = "C:\Users\Boborodono\Desktop\San_Anto...
# 3   delta  = "C:\Users\Boborodono\Desktop\San_Anto...
# 4   epsilon = "C:\Users\Boborodono\Desktop\San_Ant...
# 5   zeta = "C:\Users\Boborodono\Desktop\San_Antoni...
# 6   eta = "C:\Users\Boborodono\Desktop\San_Antonio...
# 7   theta = "C:\Users\Boborodono\Desktop\San_Anton...
# 8   iota = "C:\Users\Boborodono\Desktop\San_Antoni...
# 9   kappa = "C:\Users\Boborodono\Desktop\San_Anton...
# 10  lambda = "C:\Users\Boborodono\Desktop\San_Anto...
# 11  mu = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 12  nu = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 13  xi = "C:\Users\Boborodono\Desktop\San_Antonio\...
# 14  omicron = "C:\Users\Boborodono\Desktop\San_Ant...
# 15  pi = "C:\Users\Boborodono\Desktop\San_Antonio\...

# %%
# Reference Dataframe
parquet_quick_data_import_df = parquet_datasets_df[['File_Paths']]
parquet_quick_data_import_df
# Out:
#                                            File_Paths
# 0   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 1   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 2   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 3   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 4   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 5   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 6   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 7   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 8   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 9   C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 10  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 11  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 12  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 13  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 14  C:\Users\Boborodono\Desktop\San_Antonio\Resour...
# 15  C:\Users\Boborodono\Desktop\San_Antonio\Resour...

# %%
# Export Parquet File
parquet_datasets_df.to_csv(r'..\..\Resources\Datasets_List\Parquet\datasets_full_parquet.csv', index=False)
parquet_reference_df.to_csv(r'..\..\Resources\Datasets_List\Parquet\reference_datasets_parquet.csv', index=False)
parquet_quick_data_import_df.to_csv(r'..\..\Resources\Datasets_List\Parquet\quick_datasets_parquet.csv', index=False)
